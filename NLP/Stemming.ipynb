# %%
words = ["Eating","Eaten","eats","writing","writes","programming","programs","finally","finalize"]

# %%
from nltk.stem import PorterStemmer

# %%
stemming = PorterStemmer()

# %%
for word in words:
    print(word+"-->"+stemming.stem(word))
# Out:
# Eating-->eat
# Eaten-->eaten
# eats-->eat
# writing-->write
# writes-->write
# programming-->program
# programs-->program
# finally-->final
# finalize-->final

# %%
stemming.stem("Congratulation")
# Out:
# 'congratul'

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer = RegexpStemmer("ing$|s$|able$",min=4)

# %%
reg_stemmer.stem("eating")
# Out:
# 'eat'

# %%
reg_stemmer.stem("ingeat")
# Out:
# 'ingeat'

# %%
from nltk.stem import SnowballStemmer

# %%
s_stemmer = SnowballStemmer("english")

# %%
for word in words:
    print(word+"-->"+s_stemmer.stem(word))
# Out:
# Eating-->eat
# Eaten-->eaten
# eats-->eat
# writing-->write
# writes-->write
# programming-->program
# programs-->program
# finally-->final
# finalize-->final

# %%
s_stemmer.stem("History")
# Out:
# 'histori'

# %%
s_stemmer.stem("Fairly")
# Out:
# 'fair'
