# %%
paragraph = '''
Gojo Satoru, from *Jujutsu Kaisen*, embodies qualities that resonate beyond the realm of anime. His character—marked by unparalleled strength, charisma, and a sense of justice—serves as a metaphor for confronting challenges with confidence and resilience. In real life, Gojo's unyielding determination and ability to inspire others highlight the importance of maintaining a strong sense of purpose and leadership in the face of adversity. His role encourages individuals to embrace their unique strengths and to confront obstacles with a mindset geared toward positive change and personal growth. By reflecting on Gojo's character, people can find motivation to persevere through their own struggles and to lead with integrity and conviction.
'''

# %%
import nltk
sentences = nltk.sent_tokenize(paragraph)

# %%
sentences
# Out:
# ['\nGojo Satoru, from *Jujutsu Kaisen*, embodies qualities that resonate beyond the realm of anime.',
#  'His character—marked by unparalleled strength, charisma, and a sense of justice—serves as a metaphor for confronting challenges with confidence and resilience.',
#  "In real life, Gojo's unyielding determination and ability to inspire others highlight the importance of maintaining a strong sense of purpose and leadership in the face of adversity.",
#  'His role encourages individuals to embrace their unique strengths and to confront obstacles with a mindset geared toward positive change and personal growth.',
#  "By reflecting on Gojo's character, people can find motivation to persevere through their own struggles and to lead with integrity and conviction."]

# %%
from nltk.corpus import stopwords
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [word for word in words if word not in set (stopwords.words('english'))]
    pos_tag = nltk.pos_tag(words)
    print(pos_tag)
# Out:
# [('Gojo', 'NNP'), ('Satoru', 'NNP'), (',', ','), ('*Jujutsu', 'NNP'), ('Kaisen*', 'NNP'), (',', ','), ('embodies', 'VBZ'), ('qualities', 'NNS'), ('resonate', 'VBP'), ('beyond', 'IN'), ('realm', 'NN'), ('anime', 'NN'), ('.', '.')]
# [('His', 'PRP$'), ('character—marked', 'VBD'), ('unparalleled', 'JJ'), ('strength', 'NN'), (',', ','), ('charisma', 'NN'), (',', ','), ('sense', 'NN'), ('justice—serves', 'NNS'), ('metaphor', 'VBP'), ('confronting', 'VBG'), ('challenges', 'NNS'), ('confidence', 'NN'), ('resilience', 'NN'), ('.', '.')]
# [('In', 'IN'), ('real', 'JJ'), ('life', 'NN'), (',', ','), ('Gojo', 'NNP'), ("'s", 'POS'), ('unyielding', 'JJ'), ('determination', 'NN'), ('ability', 'NN'), ('inspire', 'NN'), ('others', 'NNS'), ('highlight', 'VBD'), ('importance', 'NN'), ('maintaining', 'NN'), ('strong', 'JJ'), ('sense', 'NN'), ('purpose', 'NN'), ('leadership', 'NN'), ('face', 'NN'), ('adversity', 'NN'), ('.', '.')]
# ...

# %%
print(nltk.pos_tag("I am the Honored One".split()))
# Out:
# [('I', 'PRP'), ('am', 'VBP'), ('the', 'DT'), ('Honored', 'NNP'), ('One', 'NN')]
